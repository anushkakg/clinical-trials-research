# %% [markdown]
# # Fields Analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt
from ctr.api import get_integer_fields

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Load Data

# %%
fields = get_integer_fields()
df = pd.DataFrame(field.model_dump() for field in fields)

# %% [markdown]
# ## Data Processing and Visualization

# %%
df[["piece", "missingStudiesCount", "min", "max", "avg"]]
# Out:
#                             piece  missingStudiesCount    min        max  \
# 0               DispFirstPostYear               481038   2009       2024
# 1             DispFirstSubmitYear               481006   2008       2024
# 2                 EnrollmentCount                 6912      0  188814085
# 3     EventGroupDeathsNumAffected               456738      0      17251
# 4       EventGroupDeathsNumAtRisk               456738      0    2019461
# 5      EventGroupOtherNumAffected               426883      0      11846
# 6        EventGroupOtherNumAtRisk               427216      0    2019461
# 7    EventGroupSeriousNumAffected               426883      0      13289
# 8      EventGroupSeriousNumAtRisk               427186      0    2019461
# 9                    LargeDocSize               456036  12395   33548883
# 10             LastUpdatePostYear                    0   2005       2024
# 11           LastUpdateSubmitYear                    0   2005       2024
# 12   NumArmGroupInterventionNames                65715      0         97
# 13                   NumArmGroups                25338      0         49
# 14                   NumAvailIPDs               298499      0         26
# 15          NumBaselineCategories               426674      0         31
# 16             NumBaselineClasses               426672      0        376
# 17              NumBaselineDenoms               426672      1          2
# 18              NumBaselineGroups               426672      1         61
# 19       NumBaselineMeasureDenoms               426672      0          2
# 20        NumBaselineMeasurements               426715      0         61
# 21            NumBaselineMeasures               426672      2         69
# 22             NumCentralContacts                15602      0          2
# 23               NumCollaborators                    0      0        180
# 24       NumCollaboratorsPlusLead                    0      1        181
# 25          NumConditionAncestors                    2      0        233
# 26     NumConditionBrowseBranches                    2      0         21
# 27        NumConditionBrowseLeafs                    2      0        590
# 28             NumConditionMeshes                    2      0        147
# 29                  NumConditions                  910      0        326
# 30            NumDesignWhoMaskeds               119130      0          4
# 31                 NumEventGroups               426877      1         75
# 32                      NumEvents               426877      0       2505
# 33            NumFlowAchievements               426672      1         60
# 34           NumFlowDropWithdraws               426672      0         50
# 35                  NumFlowGroups               426672      1         60
# 36              NumFlowMilestones               426672      3         24
# 37                 NumFlowPeriods               426672      1         31
# 38                 NumFlowReasons               451263      1         47
# 39         NumIPDSharingInfoTypes               262742      0          5
# 40       NumInterventionAncestors                    2      0        117
# 41  NumInterventionArmGroupLabels                48501      0         44
# 42  NumInterventionBrowseBranches                    2      0         32
# 43     NumInterventionBrowseLeafs                    2      0        188
# 44          NumInterventionMeshes                    2      0        139
# 45      NumInterventionOtherNames                48501      0        216
# 46               NumInterventions                25338      0         97
# 47                    NumKeywords                  910      0        489
# 48                   NumLargeDocs               456036      1         12
# 49            NumLocationContacts                51623      0         57
# 50                   NumLocations                15602      0       3511
# 51                  NumNCTAliases                    0      0         23
# 52            NumOtherEventStatss               445560      1         75
# 53                 NumOtherEvents               426877      0       1688
# 54               NumOtherOutcomes                17422      0        358
# 55             NumOutcomeAnalyses               426672      0        442
# 56     NumOutcomeAnalysisGroupIds               468190      1         72
# 57           NumOutcomeCategories               428756      0         61
# 58              NumOutcomeClasses               426672      0        892
# 59               NumOutcomeDenoms               426672      0          2
# 60               NumOutcomeGroups               426672      0         72
# 61         NumOutcomeMeasurements               428762      0         72
# 62             NumOutcomeMeasures               426672      1        338
# 63                    NumOutcomes                17422      1        464
# 64            NumOverallOfficials                15602      0        286
# 65                      NumPhases                  881      0          2
# 66             NumPrimaryOutcomes                17422      0        334
# 67                  NumReferences               298499      0        654
# 68            NumRemovedCountries                    2      0         49
# 69          NumRetractionsAllRefs               298499      0          3
# 70           NumRetractionsForRef               323002      0          2
# 71                NumSecondaryIds                    0      0         96
# 72           NumSecondaryOutcomes                17422      0        459
# 73                NumSeeAlsoLinks               298499      0         60
# 74          NumSeriousEventStatss               455272      1         75
# 75               NumSeriousEvents               426877      0       2505
# 76                     NumStdAges                  881      1          3
# 77     NumUniqueLocationCountries                15602      0         59
# 78              NumUnpostedEvents               481738      2         30
# 79             NumViolationEvents               489884      2          2
# 80     OtherEventStatsNumAffected               445562      0       6852
# 81       OtherEventStatsNumAtRisk               445560      0     185022
# 82       OtherEventStatsNumEvents               465538      0      33077
# 83           ResultsFirstPostYear               426672   2008       2024
# 84         ResultsFirstSubmitYear               426672   2008       2024
# 85   SeriousEventStatsNumAffected               455273      0      13289
# 86     SeriousEventStatsNumAtRisk               455272      0     419927
# 87     SeriousEventStatsNumEvents               470780      0      13289
# 88             StudyFirstPostYear                    0   1999       2024
# 89           StudyFirstSubmitYear                    0   1999       2024
# 90          SubmissionMCPReleaseN               488741      1        583
#
#              avg
# 0   2.015853e+03
# 1   2.015688e+03
# 2   5.303567e+03
# 3   7.211231e+00
# 4   1.889377e+02
# 5   3.965260e+01
# 6   1.664568e+02
# 7   1.355758e+01
# 8   1.747652e+02
# 9   1.685292e+06
# 10  2.018968e+03
# 11  2.018954e+03
# 12  1.218055e+00
# 13  1.914793e+00
# 14  5.485660e-02
# 15  1.744295e+00
# 16  1.341524e+00
# 17  1.005347e+00
# 18  2.919737e+00
# 19  5.229988e-03
# 20  2.928090e+00
# 21  4.911923e+00
# 22  3.971962e-01
# 23  6.035531e-01
# 24  1.603553e+00
# 25  5.126172e+00
# 26  3.414394e+00
# 27  7.723477e+00
# 28  1.695369e+00
# 29  1.740369e+00
# 30  9.571204e-01
# 31  2.453787e+00
# 32  4.329039e+01
# 33  2.651977e+00
# 34  2.034402e+00
# 35  2.392300e+00
# 36  3.253830e+00
# 37  1.248446e+00
# 38  2.946008e+00
# 39  2.681259e-01
# 40  2.484706e+00
# 41  1.308260e+00
# 42  1.616089e+00
# 43  3.153188e+00
# 44  6.297656e-01
# 45  4.949425e-01
# 46  1.788693e+00
# 47  2.600602e+00
# 48  1.498302e+00
# 49  1.938565e-01
# 50  6.379987e+00
# 51  6.623950e-03
# 52  3.500832e+00
# 53  2.488647e+01
# 54  3.237157e-01
# 55  5.234437e-01
# 56  1.940386e+00
# 57  1.038849e+00
# 58  2.994498e+00
# 59  9.916762e-01
# 60  2.366132e+00
# 61  2.418727e+00
# 62  8.082430e+00
# 63  6.260808e+00
# 64  9.825654e-01
# 65  8.122894e-01
# 66  1.994554e+00
# 67  4.540796e+00
# 68  7.079388e-02
# 69  1.713779e-03
# 70  3.774180e-04
# 71  3.022460e-01
# 72  3.942538e+00
# 73  3.316631e-01
# 74  2.990828e+00
# 75  1.840393e+01
# 76  1.884215e+00
# 77  1.355551e+00
# 78  3.366955e+00
# 79  2.000000e+00
# 80  4.105965e+00
# 81  1.201833e+02
# 82  6.092491e+00
# 83  2.017545e+03
# 84  2.017051e+03
# 85  1.072213e+00
# 86  8.526456e+02
# 87  1.309950e+00
# 88  2.015872e+03
# 89  2.015772e+03
# 90  1.161829e+01
